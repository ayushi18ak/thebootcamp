# %%
import cv2

cam = cv2.VideoCapture(0)

if cam.isOpened():
    print("Camera opened successfully!")
else:
    print("Could not open the camera.")

cam.release()
# Out:
# Camera opened successfully!

# %%
import cv2

# Initialize the webcam
cap = cv2.VideoCapture(0)

# Check if webcam opened correctly
if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    # Capture a single frame
    ret, frame = cap.read()

    if ret:
        print("Frame captured successfully!")
        
        # Display the frame
        cv2.imshow("Captured Frame", frame)
        
        # Wait for a key press
        cv2.waitKey(0)
        
        cv2.destroyAllWindows()
    else:
        print("Error: Failed to capture frame.")

# Release webcam
cap.release()
# Out:
# Frame captured successfully!

# %%
import cv2

# Initialize webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Webcam started. Press 'q' to quit.")

    while True:
        # Read a frame
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        # Display the video frame
        cv2.imshow("Webcam Feed", frame)

        # Press 'q' to stop
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # Release webcam
    cap.release()
    cv2.destroyAllWindows()

    print("Video processing stopped.")
# Out:
# Webcam started. Press 'q' to quit.
# Video processing stopped.

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Grayscale video processing started.")
    print("Press 'q' to quit.")

    while True:
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to capture frame.")
            break

        # Convert frame to grayscale
        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        # Display processed frame
        cv2.imshow("Grayscale Video", gray_frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    print("Grayscale video processing completed.")
# Out:
# Grayscale video processing started.
# Press 'q' to quit.
# Grayscale video processing completed.

# %%
cap.release()
cv2.destroyAllWindows()

print("Camera released and all windows closed.")
# Out:
# Camera released and all windows closed.
